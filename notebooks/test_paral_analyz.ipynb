# %%
# В Jupyter (notebooks/test.ipynb)
from parallel_analyzer import ParallelAnalyzer

analyzer = ParallelAnalyzer()  # загрузит все модели

# Для Excel
# analyzer.analyze_excel("мой_файл.xlsx")

# Для БД (если захотите)

from src.database import OlfactoryDB
db = OlfactoryDB("../data/olfactory.db")
df = analyzer.analyze_db_pairs(db)
# Out:
# 🔄 Загрузка моделей...
# ...
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
